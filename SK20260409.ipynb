# %% [markdown]
# <a href="https://colab.research.google.com/github/trans-omics/proteome-informatics-2026-research-notebook-2026-research-notebook-2026/blob/main/SK20260409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 研究ノート（2026-04-09）
#
# - 名前：河野信
# - テーマ：酒を飲む

# %% [markdown]
# ## 1. 今日の目的
# - 例：DIAデータからペプチド同定を行う
# - 例：MGFスペクトルを可視化する

# %% [markdown]
# ## 2. 使用データ・環境
#
# ### データ
# - ファイル名：
# - データ種別（DDA / DIA）：
#
# ### 環境
# - OS：
# - Python：
# - 使用ライブラリ：

# %%
# 必ず実行可能な形で書く（再現性）
# 例：MGF読み込み
# 図や結果を必ず残す

import matplotlib.pyplot as plt

def plot_spectrum(mz, intensity):
    plt.figure()
    plt.stem(mz, intensity, use_line_collection=True)
    plt.xlabel("m/z")
    plt.ylabel("Intensity")
    plt.title("MS/MS Spectrum")
    plt.show()

# ダミーデータ
mz = [100, 200, 300, 400]
intensity = [10, 50, 20, 80]

plot_spectrum(mz, intensity)

# %% [markdown]
# ## 4. 結果
# - スペクトルが可視化された
# - ピーク強度の偏りあり

# %% [markdown]
# ## 5. エラー・問題点
#
# ### エラーメッセージ
# （そのままコピペ）
#
# ### 原因（推測でOK）
# - 例：scan numberが欠落している可能性

# %% [markdown]
# ## 6. 考察
# - ノイズが多い → 前処理が不十分？
# - パラメータ設定の問題？

# %% [markdown]
# ## 7. 次にやること
# - msconvertのオプションを変更
# - ノイズ除去を実装
